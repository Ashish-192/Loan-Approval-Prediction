# %%
#Loan Approval Prediction
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
from sklearn import tree
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
import warnings

df = pd.read_csv('/content/LA_Dataset.csv')
df.head()
df.shape #dimensionality of the DataFrame (number of rows, number of columns)
df.head()
# Out:
#    loan_id   no_of_dependents      education  self_employed   income_annum  \
# 0        1                  2       Graduate             No        9600000
# 1        2                  0   Not Graduate            Yes        4100000
# 2        3                  3       Graduate             No        9100000
# 3        4                  3       Graduate             No        8200000
# 4        5                  5   Not Graduate            Yes        9800000
#
#     loan_amount   loan_term   cibil_score   residential_assets_value  \
# 0      29900000          12           778                    2400000
# 1      12200000           8           417                    2700000
# 2      29700000          20           506                    7100000
# 3      30700000           8           467                   18200000
# 4      24200000          20           382                   12400000
#
#     commercial_assets_value   luxury_assets_value   bank_asset_value  \
# 0                  17600000              22700000            8000000
# 1                   2200000               8800000            3300000
# 2                   4500000              33300000           12800000
# 3                   3300000              23300000            7900000
# 4                   8200000              29400000            5000000
#
#    loan_status
# 0     Approved
# 1     Rejected
# 2     Rejected
# 3     Rejected
# 4     Rejected

# %%
df.info() #Prints a concise summary of the DataFrame, including the number of non-null entries, data type of each column, and memory usage.
df.tail()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4269 entries, 0 to 4268
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   loan_id                    4269 non-null   int64
#  1    no_of_dependents          4269 non-null   int64
#  2    education                 4269 non-null   object
#  3    self_employed             4269 non-null   object
#  4    income_annum              4269 non-null   int64
#  5    loan_amount               4269 non-null   int64
#  6    loan_term                 4269 non-null   int64
#  7    cibil_score               4269 non-null   int64
#  8    residential_assets_value  4269 non-null   int64
#  9    commercial_assets_value   4269 non-null   int64
#  10   luxury_assets_value       4269 non-null   int64
#  11   bank_asset_value          4269 non-null   int64
#  12   loan_status               4269 non-null   object
# dtypes: int64(10), object(3)
# memory usage: 433.7+ KB
#       loan_id   no_of_dependents      education  self_employed   income_annum  \
# 4264     4265                  5       Graduate            Yes        1000000
# 4265     4266                  0   Not Graduate            Yes        3300000
# 4266     4267                  2   Not Graduate             No        6500000
# 4267     4268                  1   Not Graduate             No        4100000
# 4268     4269                  1       Graduate             No        9200000
#
#        loan_amount   loan_term   cibil_score   residential_assets_value  \
# 4264       2300000          12           317                    2800000
# 4265      11300000          20           559                    4200000
# 4266      23900000          18           457                    1200000
# 4267      12800000           8           780                    8200000
# 4268      29700000          10           607                   17800000
#
#        commercial_assets_value   luxury_assets_value   bank_asset_value  \
# 4264                    500000               3300000             800000
# 4265                   2900000              11000000            1900000
# 4266                  12400000              18100000            7300000
# 4267                    700000              14100000            5800000
# 4268                  11800000              35700000           12000000
#
#       loan_status
# 4264     Rejected
# 4265     Approved
# 4266     Rejected
# 4267     Approved
# 4268     Approved

# %%
df.columns
df.describe()
# Out:
#            loan_id   no_of_dependents   income_annum   loan_amount  \
# count  4269.000000        4269.000000   4.269000e+03  4.269000e+03
# mean   2135.000000           2.498712   5.059124e+06  1.513345e+07
# std    1232.498479           1.695910   2.806840e+06  9.043363e+06
# min       1.000000           0.000000   2.000000e+05  3.000000e+05
# 25%    1068.000000           1.000000   2.700000e+06  7.700000e+06
# 50%    2135.000000           3.000000   5.100000e+06  1.450000e+07
# 75%    3202.000000           4.000000   7.500000e+06  2.150000e+07
# max    4269.000000           5.000000   9.900000e+06  3.950000e+07
#
#          loan_term   cibil_score   residential_assets_value  \
# count  4269.000000   4269.000000               4.269000e+03
# mean     10.900445    599.936051               7.472617e+06
# std       5.709187    172.430401               6.503637e+06
# min       2.000000    300.000000              -1.000000e+05
# 25%       6.000000    453.000000               2.200000e+06
# 50%      10.000000    600.000000               5.600000e+06
# 75%      16.000000    748.000000               1.130000e+07
# max      20.000000    900.000000               2.910000e+07
#
#         commercial_assets_value   luxury_assets_value   bank_asset_value
# count              4.269000e+03          4.269000e+03       4.269000e+03
# mean               4.973155e+06          1.512631e+07       4.976692e+06
# std                4.388966e+06          9.103754e+06       3.250185e+06
# min                0.000000e+00          3.000000e+05       0.000000e+00
# 25%                1.300000e+06          7.500000e+06       2.300000e+06
# 50%                3.700000e+06          1.460000e+07       4.600000e+06
# 75%                7.600000e+06          2.170000e+07       7.100000e+06
# max                1.940000e+07          3.920000e+07       1.470000e+07

# %%
#Data Visualisation
sns.set(style="whitegrid")

# Plot Loan Status
plt.figure(figsize=(10, 4))
sns.countplot(x=' loan_status', data=df, palette='viridis', hue= ' education')
plt.title('Distribution of Loan Status')
plt.xlabel('Loan Status')
plt.ylabel('Count')
plt.show()

# Plot Education Level Distribution
plt.figure(figsize=(10, 4))
sns.countplot(x=' education', data=df, palette='viridis', hue = ' loan_status')
plt.title('Education Level Distribution')
plt.xlabel('Education Level')
plt.ylabel('Count')
plt.show()

# Ploting Self Employed Distribution
plt.figure(figsize=(5, 4))
sns.countplot(x=' self_employed', data=df, palette='viridis')
plt.title('Self Employed Distribution')
plt.xlabel('Self Employed')
plt.ylabel('Count')
plt.show()

# Ploting Income Distribution
plt.figure(figsize=(10, 6))
sns.histplot(df[' income_annum'], kde=True, bins=30, color='purple')
plt.title('Income Distribution')
plt.xlabel('Annual Income')
plt.ylabel('Frequency')
plt.show()

# Plot Loan Amount Distribution
plt.figure(figsize=(7, 4))
sns.histplot(df[' loan_amount'], kde=True, bins=30, color='blue')
plt.title('Loan Amount Distribution')
plt.xlabel('Loan Amount')
plt.ylabel('Frequency')
plt.show()

# Plot Income vs Loan Amount
plt.figure(figsize=(12, 6))
sns.scatterplot(x=' residential_assets_value', y=' income_annum', hue=' loan_status', data=df, palette='viridis')
plt.title('Income Amount vs Loan Amount Scatterplot')
plt.xlabel('Annual Income')
plt.ylabel('Loan Amount')
plt.show()

# %%
#Data Preprocessing
# Filter very low residential_assets
df = df[df[' residential_assets_value'] >= 10000]
df.describe()
# Out:
#            loan_id   no_of_dependents   income_annum   loan_amount  \
# count  4196.000000        4196.000000   4.196000e+03  4.196000e+03
# mean   2135.894185           2.497140   5.096711e+06  1.524278e+07
# std    1231.418202           1.695747   2.792720e+06  9.009593e+06
# min       1.000000           0.000000   2.000000e+05  3.000000e+05
# 25%    1071.750000           1.000000   2.700000e+06  7.800000e+06
# 50%    2136.500000           3.000000   5.100000e+06  1.465000e+07
# 75%    3201.250000           4.000000   7.500000e+06  2.160000e+07
# max    4269.000000           5.000000   9.900000e+06  3.950000e+07
#
#          loan_term   cibil_score   residential_assets_value  \
# count  4196.000000   4196.000000               4.196000e+03
# mean     10.901335    599.639895               7.603289e+06
# std       5.707598    172.480726               6.483402e+06
# min       2.000000    300.000000               1.000000e+05
# 25%       6.000000    453.000000               2.300000e+06
# 50%      10.000000    599.000000               5.800000e+06
# 75%      16.000000    748.000000               1.140000e+07
# max      20.000000    900.000000               2.910000e+07
#
#         commercial_assets_value   luxury_assets_value   bank_asset_value
# count              4.196000e+03          4.196000e+03       4.196000e+03
# mean               4.999809e+06          1.524345e+07       5.015038e+06
# std                4.383745e+06          9.071128e+06       3.243334e+06
# min                0.000000e+00          3.000000e+05       0.000000e+00
# 25%                1.400000e+06          7.600000e+06       2.400000e+06
# 50%                3.700000e+06          1.470000e+07       4.600000e+06
# 75%                7.700000e+06          2.180000e+07       7.100000e+06
# max                1.940000e+07          3.920000e+07       1.470000e+07

# %%
df.dtypes
# Out:
# loan_id                       int64
#  no_of_dependents             int64
#  education                   object
#  self_employed               object
#  income_annum                 int64
#  loan_amount                  int64
#  loan_term                    int64
#  cibil_score                  int64
#  residential_assets_value     int64
#  commercial_assets_value      int64
#  luxury_assets_value          int64
#  bank_asset_value             int64
#  loan_status                 object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4196 entries, 0 to 4268
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   loan_id                    4196 non-null   int64
#  1    no_of_dependents          4196 non-null   int64
#  2    education                 4196 non-null   object
#  3    self_employed             4196 non-null   object
#  4    income_annum              4196 non-null   int64
#  5    loan_amount               4196 non-null   int64
#  6    loan_term                 4196 non-null   int64
#  7    cibil_score               4196 non-null   int64
#  8    residential_assets_value  4196 non-null   int64
#  9    commercial_assets_value   4196 non-null   int64
#  10   luxury_assets_value       4196 non-null   int64
#  11   bank_asset_value          4196 non-null   int64
#  12   loan_status               4196 non-null   object
# dtypes: int64(10), object(3)
# memory usage: 458.9+ KB

# %%
#Check duplicate in dataframe
df.duplicated().sum()
# Out:
# 0

# %%
#check for missing values
df.isnull().sum()
# Out:
# loan_id                      0
#  no_of_dependents            0
#  education                   0
#  self_employed               0
#  income_annum                0
#  loan_amount                 0
#  loan_term                   0
#  cibil_score                 0
#  residential_assets_value    0
#  commercial_assets_value     0
#  luxury_assets_value         0
#  bank_asset_value            0
#  loan_status                 0
# dtype: int64

# %%
df.columns=[s.strip() for s in df.columns]
df.columns
# Out:
# Index(['loan_id', 'no_of_dependents', 'education', 'self_employed',
#        'income_annum', 'loan_amount', 'loan_term', 'cibil_score',
#        'residential_assets_value', 'commercial_assets_value',
#        'luxury_assets_value', 'bank_asset_value', 'loan_status'],
#       dtype='object')

# %%
df.head()
# Out:
#    loan_id  no_of_dependents      education self_employed  income_annum  \
# 0        1                 2       Graduate            No       9600000
# 1        2                 0   Not Graduate           Yes       4100000
# 2        3                 3       Graduate            No       9100000
# 3        4                 3       Graduate            No       8200000
# 4        5                 5   Not Graduate           Yes       9800000
#
#    loan_amount  loan_term  cibil_score  residential_assets_value  \
# 0     29900000         12          778                   2400000
# 1     12200000          8          417                   2700000
# 2     29700000         20          506                   7100000
# 3     30700000          8          467                  18200000
# 4     24200000         20          382                  12400000
#
#    commercial_assets_value  luxury_assets_value  bank_asset_value loan_status
# 0                 17600000             22700000           8000000    Approved
# 1                  2200000              8800000           3300000    Rejected
# 2                  4500000             33300000          12800000    Rejected
# 3                  3300000             23300000           7900000    Rejected
# 4                  8200000             29400000           5000000    Rejected

# %%
#Categorical Variables to Numeric Encoding
education_mapping = {
    ' Graduate': 1,
    ' Not Graduate': 0
}

self_employed_mapping = {
    ' Yes': 1,
    ' No': 0
}

loan_status_mapping = {
    ' Approved': 1,
    ' Rejected': 0
}

# %%
df['education'] = df['education'].map(education_mapping)
df['self_employed'] = df['self_employed'].map(self_employed_mapping)
df['loan_status'] = df['loan_status'].map(loan_status_mapping)

# %%
#Outlier Treatment
#Finding the maximum value in all assets value
Columns_to_select = ['income_annum', 'loan_amount', 'residential_assets_value', 'commercial_assets_value', 'luxury_assets_value', 'bank_asset_value']
df[Columns_to_select].max()
# Out:
# income_annum                 9900000
# loan_amount                 39500000
# residential_assets_value    29100000
# commercial_assets_value     19400000
# luxury_assets_value         39200000
# bank_asset_value            14700000
# dtype: int64

# %%
df[Columns_to_select].describe()
# Out:
#        income_annum   loan_amount  residential_assets_value  \
# count  4.196000e+03  4.196000e+03              4.196000e+03
# mean   5.096711e+06  1.524278e+07              7.603289e+06
# std    2.792720e+06  9.009593e+06              6.483402e+06
# min    2.000000e+05  3.000000e+05              1.000000e+05
# 25%    2.700000e+06  7.800000e+06              2.300000e+06
# 50%    5.100000e+06  1.465000e+07              5.800000e+06
# 75%    7.500000e+06  2.160000e+07              1.140000e+07
# max    9.900000e+06  3.950000e+07              2.910000e+07
#
#        commercial_assets_value  luxury_assets_value  bank_asset_value
# count             4.196000e+03         4.196000e+03      4.196000e+03
# mean              4.999809e+06         1.524345e+07      5.015038e+06
# std               4.383745e+06         9.071128e+06      3.243334e+06
# min               0.000000e+00         3.000000e+05      0.000000e+00
# 25%               1.400000e+06         7.600000e+06      2.400000e+06
# 50%               3.700000e+06         1.470000e+07      4.600000e+06
# 75%               7.700000e+06         2.180000e+07      7.100000e+06
# max               1.940000e+07         3.920000e+07      1.470000e+07

# %%
#Calculating IQR
Q1 = df[Columns_to_select].quantile(0.25)
Q3 = df[Columns_to_select].quantile(0.75)

# Calculate IQR
IQR = Q3 - Q1
IQR
# Out:
# income_annum                 4800000.0
# loan_amount                 13800000.0
# residential_assets_value     9100000.0
# commercial_assets_value      6300000.0
# luxury_assets_value         14200000.0
# bank_asset_value             4700000.0
# dtype: float64

# %%
# Define the boundaries
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers = df[(df[Columns_to_select] < lower_bound) | (df[Columns_to_select] > upper_bound)]
print("Outliers using IQR method:")
print(outliers)
# Out:
# Outliers using IQR method:
#       loan_id  no_of_dependents  education  self_employed  income_annum  \
# 0         NaN               NaN        NaN            NaN           NaN
# 1         NaN               NaN        NaN            NaN           NaN
# 2         NaN               NaN        NaN            NaN           NaN
# 3         NaN               NaN        NaN            NaN           NaN
# 4         NaN               NaN        NaN            NaN           NaN
# ...       ...               ...        ...            ...           ...
# 4264      NaN               NaN        NaN            NaN           NaN
# 4265      NaN               NaN        NaN            NaN           NaN
# 4266      NaN               NaN        NaN            NaN           NaN
# 4267      NaN               NaN        NaN            NaN           NaN
# 4268      NaN               NaN        NaN            NaN           NaN
#
#       loan_amount  loan_term  cibil_score  residential_assets_value  \
# 0             NaN        NaN          NaN                       NaN
# 1             NaN        NaN          NaN                       NaN
# 2             NaN        NaN          NaN                       NaN
# 3             NaN        NaN          NaN                       NaN
# 4             NaN        NaN          NaN                       NaN
# ...           ...        ...          ...                       ...
# 4264          NaN        NaN          NaN                       NaN
# 4265          NaN        NaN          NaN                       NaN
# 4266          NaN        NaN          NaN                       NaN
# 4267          NaN        NaN          NaN                       NaN
# 4268          NaN        NaN          NaN                       NaN
#
#       commercial_assets_value  luxury_assets_value  bank_asset_value  \
# 0                  17600000.0                  NaN               NaN
# 1                         NaN                  NaN               NaN
# 2                         NaN                  NaN               NaN
# 3                         NaN                  NaN               NaN
# 4                         NaN                  NaN               NaN
# ...                       ...                  ...               ...
# 4264                      NaN                  NaN               NaN
# 4265                      NaN                  NaN               NaN
# 4266                      NaN                  NaN               NaN
# 4267                      NaN                  NaN               NaN
# 4268                      NaN                  NaN               NaN
#
#       loan_status
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 4264          NaN
# 4265          NaN
# 4266          NaN
# 4267          NaN
# 4268          NaN
#
# [4196 rows x 13 columns]

# %%
# Remove outliers
df_cleaned = df[~((df[Columns_to_select] < lower_bound) | (df[Columns_to_select] > upper_bound))]
print("DataFrame after removing outliers:")
print(df_cleaned)
# Out:
# DataFrame after removing outliers:
#       loan_id  no_of_dependents  education  self_employed  income_annum  \
# 0         NaN               NaN        NaN            NaN       9600000
# 1         NaN               NaN        NaN            NaN       4100000
# 2         NaN               NaN        NaN            NaN       9100000
# 3         NaN               NaN        NaN            NaN       8200000
# 4         NaN               NaN        NaN            NaN       9800000
# ...       ...               ...        ...            ...           ...
# 4264      NaN               NaN        NaN            NaN       1000000
# 4265      NaN               NaN        NaN            NaN       3300000
# 4266      NaN               NaN        NaN            NaN       6500000
# 4267      NaN               NaN        NaN            NaN       4100000
# 4268      NaN               NaN        NaN            NaN       9200000
#
#       loan_amount  loan_term  cibil_score  residential_assets_value  \
# 0        29900000        NaN          NaN                 2400000.0
# 1        12200000        NaN          NaN                 2700000.0
# 2        29700000        NaN          NaN                 7100000.0
# 3        30700000        NaN          NaN                18200000.0
# 4        24200000        NaN          NaN                12400000.0
# ...           ...        ...          ...                       ...
# 4264      2300000        NaN          NaN                 2800000.0
# 4265     11300000        NaN          NaN                 4200000.0
# 4266     23900000        NaN          NaN                 1200000.0
# 4267     12800000        NaN          NaN                 8200000.0
# 4268     29700000        NaN          NaN                17800000.0
#
#       commercial_assets_value  luxury_assets_value  bank_asset_value  \
# 0                         NaN             22700000         8000000.0
# 1                   2200000.0              8800000         3300000.0
# 2                   4500000.0             33300000        12800000.0
# 3                   3300000.0             23300000         7900000.0
# 4                   8200000.0             29400000         5000000.0
# ...                       ...                  ...               ...
# 4264                 500000.0              3300000          800000.0
# 4265                2900000.0             11000000         1900000.0
# 4266               12400000.0             18100000         7300000.0
# 4267                 700000.0             14100000         5800000.0
# 4268               11800000.0             35700000        12000000.0
#
#       loan_status
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 4264          NaN
# 4265          NaN
# 4266          NaN
# 4267          NaN
# 4268          NaN
#
# [4196 rows x 13 columns]

# %%
# same shape of original and cleared df (no Outliers in df)
df_cleaned.shape
# Out:
# (4196, 13)

# %%
corr_matrix = df.corr()
corr_matrix
# Out:
#                            loan_id  no_of_dependents  education  \
# loan_id                   1.000000          0.004839   0.016121
# no_of_dependents          0.004839          1.000000   0.005208
# education                 0.016121          0.005208   1.000000
# self_employed             0.000846          0.001839  -0.024817
# income_annum              0.013591          0.012104   0.011322
# loan_amount               0.008966          0.000514   0.010972
# loan_term                 0.004771         -0.020004  -0.008278
# cibil_score               0.017258         -0.004770  -0.007679
# residential_assets_value  0.020540          0.008622   0.011365
# commercial_assets_value   0.019470          0.001815  -0.007971
# luxury_assets_value       0.000190          0.006716   0.011034
# bank_asset_value          0.010853          0.015592   0.009394
# loan_status               0.017458         -0.015521   0.002357
#
#                           self_employed  income_annum  loan_amount  loan_term  \
# loan_id                        0.000846      0.013591     0.008966   0.004771
# no_of_dependents               0.001839      0.012104     0.000514  -0.020004
# education                     -0.024817      0.011322     0.010972  -0.008278
# self_employed                  1.000000     -0.000845    -0.002169   0.005302
# income_annum                  -0.000845      1.000000     0.926190   0.016275
# loan_amount                   -0.002169      0.926190     1.000000   0.012494
# loan_term                      0.005302      0.016275     0.012494   1.000000
# cibil_score                   -0.008040     -0.022928    -0.016818   0.008528
# residential_assets_value       0.006408      0.637360     0.594793   0.007995
# commercial_assets_value       -0.023239      0.635200     0.597987  -0.001319
# luxury_assets_value            0.001056      0.928011     0.858419   0.016414
# bank_asset_value              -0.001569      0.849273     0.785469   0.021592
# loan_status                   -0.002298     -0.019051     0.013227  -0.114943
#
#                           cibil_score  residential_assets_value  \
# loan_id                      0.017258                  0.020540
# no_of_dependents            -0.004770                  0.008622
# education                   -0.007679                  0.011365
# self_employed               -0.008040                  0.006408
# income_annum                -0.022928                  0.637360
# loan_amount                 -0.016818                  0.594793
# loan_term                    0.008528                  0.007995
# cibil_score                  1.000000                 -0.018315
# residential_assets_value    -0.018315                  1.000000
# commercial_assets_value     -0.003743                  0.416651
# luxury_assets_value         -0.029187                  0.590036
# bank_asset_value            -0.014921                  0.525468
# loan_status                  0.770977                 -0.015493
#
#                           commercial_assets_value  luxury_assets_value  \
# loan_id                                  0.019470             0.000190
# no_of_dependents                         0.001815             0.006716
# education                               -0.007971             0.011034
# self_employed                           -0.023239             0.001056
# income_annum                             0.635200             0.928011
# loan_amount                              0.597987             0.858419
# loan_term                               -0.001319             0.016414
# cibil_score                             -0.003743            -0.029187
# residential_assets_value                 0.416651             0.590036
# commercial_assets_value                  1.000000             0.585445
# luxury_assets_value                      0.585445             1.000000
# bank_asset_value                         0.544214             0.785948
# loan_status                              0.005597            -0.019664
#
#                           bank_asset_value  loan_status
# loan_id                           0.010853     0.017458
# no_of_dependents                  0.015592    -0.015521
# education                         0.009394     0.002357
# self_employed                    -0.001569    -0.002298
# income_annum                      0.849273    -0.019051
# loan_amount                       0.785469     0.013227
# loan_term                         0.021592    -0.114943
# cibil_score                      -0.014921     0.770977
# residential_assets_value          0.525468    -0.015493
# commercial_assets_value           0.544214     0.005597
# luxury_assets_value               0.785948    -0.019664
# bank_asset_value                  1.000000    -0.010154
# loan_status                      -0.010154     1.000000

# %%
# Seting matplotlib figure
plt.figure(figsize=(8, 4))
# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', center=0, linewidths=0.5, fmt='.2f')
plt.title('Correlation Matrix Heatmap')
plt.show()

# %%
# Function to identify and filter features based on correlation threshold
def filter_features_by_correlation(df, threshold):
    corr_matrix = df.corr()
    high_corr_features = set()

    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i, j]) > threshold:
                colname = corr_matrix.columns[i]
                high_corr_features.add(colname)

    # Filter the DataFrame and get removed features
    # This line should be indented within the function
    filtered_df = df.drop(columns=high_corr_features)
    return filtered_df, high_corr_features  # Return the filtered DataFrame and removed features
filtered_df, removed_features = filter_features_by_correlation(df, 0.8)
filtered_df.head()
# Out:
#    loan_id  no_of_dependents  education  self_employed  income_annum  \
# 0        1                 2          1              0       9600000
# 1        2                 0          0              1       4100000
# 2        3                 3          1              0       9100000
# 3        4                 3          1              0       8200000
# 4        5                 5          0              1       9800000
#
#    loan_term  cibil_score  residential_assets_value  commercial_assets_value  \
# 0         12          778                   2400000                 17600000
# 1          8          417                   2700000                  2200000
# 2         20          506                   7100000                  4500000
# 3          8          467                  18200000                  3300000
# 4         20          382                  12400000                  8200000
#
#    loan_status
# 0            1
# 1            0
# 2            0
# 3            0
# 4            0

# %%
removed_features
# Out:
# {'bank_asset_value', 'loan_amount', 'luxury_assets_value'}

# %%
#Feature Scaling (Normalization)
from sklearn.preprocessing import MinMaxScaler
mms = MinMaxScaler()
filtered_df[['income_annum','loan_term','cibil_score','residential_assets_value','commercial_assets_value']] = mms.fit_transform(filtered_df[['income_annum','loan_term','cibil_score','residential_assets_value','commercial_assets_value']])
filtered_df.head()
# Out:
#    loan_id  no_of_dependents  education  self_employed  income_annum  \
# 0        1                 2          1              0      0.969072
# 1        2                 0          0              1      0.402062
# 2        3                 3          1              0      0.917526
# 3        4                 3          1              0      0.824742
# 4        5                 5          0              1      0.989691
#
#    loan_term  cibil_score  residential_assets_value  commercial_assets_value  \
# 0   0.555556     0.796667                  0.079310                 0.907216
# 1   0.333333     0.195000                  0.089655                 0.113402
# 2   1.000000     0.343333                  0.241379                 0.231959
# 3   0.333333     0.278333                  0.624138                 0.170103
# 4   1.000000     0.136667                  0.424138                 0.422680
#
#    loan_status
# 0            1
# 1            0
# 2            0
# 3            0
# 4            0

# %%
#Selecting the Input and Output features for modelling
X = filtered_df.drop(columns=['loan_id', 'loan_status'])
y = filtered_df['loan_status']
X.head()
# Out:
#    no_of_dependents  education  self_employed  income_annum  loan_term  \
# 0                 2          1              0      0.969072   0.555556
# 1                 0          0              1      0.402062   0.333333
# 2                 3          1              0      0.917526   1.000000
# 3                 3          1              0      0.824742   0.333333
# 4                 5          0              1      0.989691   1.000000
#
#    cibil_score  residential_assets_value  commercial_assets_value
# 0     0.796667                  0.079310                 0.907216
# 1     0.195000                  0.089655                 0.113402
# 2     0.343333                  0.241379                 0.231959
# 3     0.278333                  0.624138                 0.170103
# 4     0.136667                  0.424138                 0.422680

# %%
#Data Modelling (Splittling data into training and testing)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=56)
# Create an empty DataFrame with the specified columns
report = pd.DataFrame(columns=["model name", "accuracy score"])
dt_clf = tree.DecisionTreeClassifier()
dt_clf.fit(X_train, y_train)
y_pred_tree = dt_clf.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred_tree))
print(classification_report(y_test, y_pred_tree))
# Out:
# Accuracy: 0.9579030976965845
#               precision    recall  f1-score   support
#
#            0       0.95      0.94      0.95       493
#            1       0.96      0.97      0.97       766
#
#     accuracy                           0.96      1259
#    macro avg       0.96      0.95      0.96      1259
# weighted avg       0.96      0.96      0.96      1259

# %%
#Appending a new row using concat
new_row = pd.DataFrame([{"model name": "DecisionTreeClassifier", "accuracy score": accuracy_score(y_test, y_pred_tree)}])
report = pd.concat([report, new_row], ignore_index=True)
warnings.filterwarnings("ignore")
rf_clf = RandomForestClassifier(n_estimators=50, max_depth=5, random_state=7)
rf_clf.fit(X_train, y_train)
y_pred_forest = rf_clf.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred_forest))
print(classification_report(y_test, y_pred_forest))
# Out:
# Accuracy: 0.9579030976965845
#               precision    recall  f1-score   support
#
#            0       0.94      0.95      0.95       493
#            1       0.97      0.96      0.97       766
#
#     accuracy                           0.96      1259
#    macro avg       0.96      0.96      0.96      1259
# weighted avg       0.96      0.96      0.96      1259

# %%
#Implementing K Nearest Neighbour Classifier model
knn = KNeighborsClassifier(n_neighbors=30)
knn.fit(X_train, y_train)
y_pred_knn = knn.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred_knn))
print(classification_report(y_test, y_pred_knn))
# Appending a new row using concat
new_row = pd.DataFrame([{"model name": "KNeighborsClassifier", "accuracy score":accuracy_score(y_test, y_pred_knn)}])
report = pd.concat([report, new_row], ignore_index=True)
warnings.filterwarnings("ignore")
# Out:
# Accuracy: 0.8927720413026211
#               precision    recall  f1-score   support
#
#            0       0.89      0.83      0.86       493
#            1       0.90      0.93      0.91       766
#
#     accuracy                           0.89      1259
#    macro avg       0.89      0.88      0.89      1259
# weighted avg       0.89      0.89      0.89      1259

# %%
#Implementing Logistic Regression model
#Appending a new row using concat
new_row = pd.DataFrame([{"model name": "RandomForestClassifier", "accuracy score":accuracy_score(y_test, y_pred_forest)}])
report = pd.concat([report, new_row], ignore_index=True)
warnings.filterwarnings("ignore")
lr_model = LogisticRegression(max_iter=1000)
lr_model.fit(X_train, y_train)
y_pred = lr_model.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.9086576648133439
#               precision    recall  f1-score   support
#
#            0       0.89      0.87      0.88       493
#            1       0.92      0.93      0.93       766
#
#     accuracy                           0.91      1259
#    macro avg       0.91      0.90      0.90      1259
# weighted avg       0.91      0.91      0.91      1259

# %%
#Appending a new row using concat
new_row = pd.DataFrame([{"model name": "LogisticRegression", "accuracy score":accuracy_score(y_test, y_pred)}])
report = pd.concat([report, new_row], ignore_index=True)
warnings.filterwarnings("ignore")
#Implementing Support Vector Machine model
svm = SVC(kernel='linear')
svm.fit(X_train, y_train)
y_pred_svm = svm.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred_svm))
print(classification_report(y_test, y_pred_svm))
#Appending a new row using concat
new_row = pd.DataFrame([{"model name": "SVC", "accuracy score":accuracy_score(y_test, y_pred_svm)}])
report = pd.concat([report, new_row], ignore_index=True)
warnings.filterwarnings("ignore")
# Out:
# Accuracy: 0.9213661636219221
#               precision    recall  f1-score   support
#
#            0       0.90      0.90      0.90       493
#            1       0.94      0.93      0.94       766
#
#     accuracy                           0.92      1259
#    macro avg       0.92      0.92      0.92      1259
# weighted avg       0.92      0.92      0.92      1259

# %%
# Tabular representation of all the models with their accuracy score
report
# Out:
#                model name  accuracy score
# 0  DecisionTreeClassifier        0.957903
# 1    KNeighborsClassifier        0.892772
# 2  RandomForestClassifier        0.957903
# 3      LogisticRegression        0.908658
# 4                     SVC        0.921366
